# %% [markdown]
# <a href="https://colab.research.google.com/github/Nobel712/Image-Segmentation/blob/main/double_Unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,BatchNormalization,Activation,MaxPool2D,Conv2DTranspose,Concatenate,Input
from tensorflow.keras.layers import GlobalAveragePooling2D,Reshape,Dense,Multiply,AveragePooling2D,UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

# %%
def squeeze_excite_block(inputs, ratio=8):
    init = inputs       ## (b, 128, 128, 32)
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)     ## (b, 32)   -> (b, 1, 1, 32)
    se = Reshape(se_shape)(se)
    se = Dense(filters//ratio, activation="relu", use_bias=False)(se)
    se = Dense(filters, activation="sigmoid", use_bias=False)(se)

    x = Multiply()([inputs, se])
    return x

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=6, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=12, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=18, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
def conv_block(x, filters):
    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = squeeze_excite_block(x)

    return x

# %%
def encoder1(inputs):
    skip_connections = []

    model = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)
    names = ["block1_conv2", "block2_conv2", "block3_conv4", "block4_conv4"]
    for name in names:
        skip_connections.append(model.get_layer(name).output)

    output = model.get_layer("block5_conv4").output
    return output, skip_connections

# %%
def decoder1(inputs, skip_connections):
    num_filters = [256, 128, 64, 32]
    skip_connections.reverse()

    x = inputs
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip_connections[i]])
        x = conv_block(x, f)

    return x

# %%
def output_block(inputs):
    x = Conv2D(1, 1, padding="same")(inputs)
    x = Activation("sigmoid")(x)
    return x

# %%
def encoder2(inputs):
    num_filters = [32, 64, 128, 256]
    skip_connections = []

    x = inputs
    for i, f in enumerate(num_filters):
        x = conv_block(x, f)
        skip_connections.append(x)
        x = MaxPool2D((2, 2))(x)

    return x, skip_connections

# %%
def decoder2(inputs, skip_1, skip_2):
    num_filters = [256, 128, 64, 32]
    skip_2.reverse()

    x = inputs
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip_1[i], skip_2[i]])
        x = conv_block(x, f)

    return x

# %%
def build_model(input_shape):
    inputs = Input(input_shape)
    x, skip_1 = encoder1(inputs)
    x = ASPP(x, 64)
    x = decoder1(x, skip_1)
    output1 = output_block(x)

    x = inputs * output1

    x, skip_2 = encoder2(x)
    x = ASPP(x, 64)
    x = decoder2(x, skip_1, skip_2)
    output2 = output_block(x)

    outputs = Concatenate()([output1, output2])
    model = Model(inputs, outputs)
    return model

# %%
if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = build_model(input_shape)
    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 64  1792        ['input_3[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 128, 128, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 64, 64, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 512)  0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv3[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 1, 1, 512)   0           ['block5_conv4[0][0]']
#  oling2D)
#
#  conv2d_46 (Conv2D)             (None, 1, 1, 64)     32832       ['average_pooling2d_3[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 1, 1, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 64)   32768       ['block5_conv4[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 64)   294912      ['block5_conv4[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 64)   294912      ['block5_conv4[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 64)   294912      ['block5_conv4[0][0]']
#
#  activation_45 (Activation)     (None, 1, 1, 64)     0           ['batch_normalization_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 64)  256         ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 64)  256         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 64)  256         ['conv2d_50[0][0]']
#  ormalization)
#
#  up_sampling2d_12 (UpSampling2D  (None, 16, 16, 64)  0           ['activation_45[0][0]']
#  )
#
#  activation_46 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_45[0][0]']
#
#  activation_47 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_46[0][0]']
#
#  activation_48 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_47[0][0]']
#
#  activation_49 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_48[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 16, 16, 320)  0           ['up_sampling2d_12[0][0]',
#                                                                   'activation_46[0][0]',
#                                                                   'activation_47[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 64)   20480       ['concatenate_12[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 16, 16, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_49[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 32, 32, 64)  0           ['activation_50[0][0]']
#  )
#
#  concatenate_13 (Concatenate)   (None, 32, 32, 576)  0           ['up_sampling2d_13[0][0]',
#                                                                   'block4_conv4[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 256)  1327360     ['concatenate_13[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_51[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_51[0][0]']
#
#  global_average_pooling2d_12 (G  (None, 256)         0           ['activation_52[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_12 (Reshape)           (None, 1, 1, 256)    0           ['global_average_pooling2d_12[0][
#                                                                  0]']
#
#  dense_24 (Dense)               (None, 1, 1, 32)     8192        ['reshape_12[0][0]']
#
#  dense_25 (Dense)               (None, 1, 1, 256)    8192        ['dense_24[0][0]']
#
#  multiply_12 (Multiply)         (None, 32, 32, 256)  0           ['activation_52[0][0]',
#                                                                   'dense_25[0][0]']
#
#  up_sampling2d_14 (UpSampling2D  (None, 64, 64, 256)  0          ['multiply_12[0][0]']
#  )
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 512)  0           ['up_sampling2d_14[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 128)  589952      ['concatenate_14[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 128)  512        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_53[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 64, 64, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_53[0][0]']
#
#  global_average_pooling2d_13 (G  (None, 128)         0           ['activation_54[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_13 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_13[0][
#                                                                  0]']
#
#  dense_26 (Dense)               (None, 1, 1, 16)     2048        ['reshape_13[0][0]']
#
#  dense_27 (Dense)               (None, 1, 1, 128)    2048        ['dense_26[0][0]']
#
#  multiply_13 (Multiply)         (None, 64, 64, 128)  0           ['activation_54[0][0]',
#                                                                   'dense_27[0][0]']
#
#  up_sampling2d_15 (UpSampling2D  (None, 128, 128, 12  0          ['multiply_13[0][0]']
#  )                              8)
#
#  concatenate_15 (Concatenate)   (None, 128, 128, 25  0           ['up_sampling2d_15[0][0]',
#                                 6)                                'block2_conv2[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 64  147520      ['concatenate_15[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 128, 128, 64  256        ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  activation_55 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_54[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 64  36928       ['activation_55[0][0]']
#                                 )
#
#  batch_normalization_55 (BatchN  (None, 128, 128, 64  256        ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  activation_56 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_55[0][0]']
#                                 )
#
#  global_average_pooling2d_14 (G  (None, 64)          0           ['activation_56[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_14 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_14[0][
#                                                                  0]']
#
#  dense_28 (Dense)               (None, 1, 1, 8)      512         ['reshape_14[0][0]']
#
#  dense_29 (Dense)               (None, 1, 1, 64)     512         ['dense_28[0][0]']
#
#  multiply_14 (Multiply)         (None, 128, 128, 64  0           ['activation_56[0][0]',
#                                 )                                 'dense_29[0][0]']
#
#  up_sampling2d_16 (UpSampling2D  (None, 256, 256, 64  0          ['multiply_14[0][0]']
#  )                              )
#
#  concatenate_16 (Concatenate)   (None, 256, 256, 12  0           ['up_sampling2d_16[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 256, 256, 32  36896       ['concatenate_16[0][0]']
#                                 )
#
#  batch_normalization_56 (BatchN  (None, 256, 256, 32  128        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  activation_57 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_56[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 256, 256, 32  9248        ['activation_57[0][0]']
#                                 )
#
#  batch_normalization_57 (BatchN  (None, 256, 256, 32  128        ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  activation_58 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_57[0][0]']
#                                 )
#
#  global_average_pooling2d_15 (G  (None, 32)          0           ['activation_58[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_15 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_15[0][
#                                                                  0]']
#
#  dense_30 (Dense)               (None, 1, 1, 4)      128         ['reshape_15[0][0]']
#
#  dense_31 (Dense)               (None, 1, 1, 32)     128         ['dense_30[0][0]']
#
#  multiply_15 (Multiply)         (None, 256, 256, 32  0           ['activation_58[0][0]',
#                                 )                                 'dense_31[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 256, 256, 1)  33          ['multiply_15[0][0]']
#
#  activation_59 (Activation)     (None, 256, 256, 1)  0           ['conv2d_60[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 256, 256, 3)  0          ['input_3[0][0]',
#  )                                                                'activation_59[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 256, 256, 32  896         ['tf.math.multiply_1[0][0]']
#                                 )
#
#  batch_normalization_58 (BatchN  (None, 256, 256, 32  128        ['conv2d_61[0][0]']
#  ormalization)                  )
#
#  activation_60 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_58[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 32  9248        ['activation_60[0][0]']
#                                 )
#
#  batch_normalization_59 (BatchN  (None, 256, 256, 32  128        ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  activation_61 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_59[0][0]']
#                                 )
#
#  global_average_pooling2d_16 (G  (None, 32)          0           ['activation_61[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_16 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_16[0][
#                                                                  0]']
#
#  dense_32 (Dense)               (None, 1, 1, 4)      128         ['reshape_16[0][0]']
#
#  dense_33 (Dense)               (None, 1, 1, 32)     128         ['dense_32[0][0]']
#
#  multiply_16 (Multiply)         (None, 256, 256, 32  0           ['activation_61[0][0]',
#                                 )                                 'dense_33[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32  0          ['multiply_16[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_60 (BatchN  (None, 128, 128, 64  256        ['conv2d_63[0][0]']
#  ormalization)                  )
#
#  activation_62 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_60[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 128, 128, 64  36928       ['activation_62[0][0]']
#                                 )
#
#  batch_normalization_61 (BatchN  (None, 128, 128, 64  256        ['conv2d_64[0][0]']
#  ormalization)                  )
#
#  activation_63 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_61[0][0]']
#                                 )
#
#  global_average_pooling2d_17 (G  (None, 64)          0           ['activation_63[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_17 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_17[0][
#                                                                  0]']
#
#  dense_34 (Dense)               (None, 1, 1, 8)      512         ['reshape_17[0][0]']
#
#  dense_35 (Dense)               (None, 1, 1, 64)     512         ['dense_34[0][0]']
#
#  multiply_17 (Multiply)         (None, 128, 128, 64  0           ['activation_63[0][0]',
#                                 )                                 'dense_35[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['multiply_17[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 64, 64, 128)  512        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_64[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 64, 64, 128)  512        ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_63[0][0]']
#
#  global_average_pooling2d_18 (G  (None, 128)         0           ['activation_65[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_18 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_18[0][
#                                                                  0]']
#
#  dense_36 (Dense)               (None, 1, 1, 16)     2048        ['reshape_18[0][0]']
#
#  dense_37 (Dense)               (None, 1, 1, 128)    2048        ['dense_36[0][0]']
#
#  multiply_18 (Multiply)         (None, 64, 64, 128)  0           ['activation_65[0][0]',
#                                                                   'dense_37[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0          ['multiply_18[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_64[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_66[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_65[0][0]']
#
#  global_average_pooling2d_19 (G  (None, 256)         0           ['activation_67[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_19 (Reshape)           (None, 1, 1, 256)    0           ['global_average_pooling2d_19[0][
#                                                                  0]']
#
#  dense_38 (Dense)               (None, 1, 1, 32)     8192        ['reshape_19[0][0]']
#
#  dense_39 (Dense)               (None, 1, 1, 256)    8192        ['dense_38[0][0]']
#
#  multiply_19 (Multiply)         (None, 32, 32, 256)  0           ['activation_67[0][0]',
#                                                                   'dense_39[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0          ['multiply_19[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 1, 1, 256)   0           ['max_pooling2d_7[0][0]']
#  oling2D)
#
#  conv2d_69 (Conv2D)             (None, 1, 1, 64)     16448       ['average_pooling2d_4[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 1, 1, 64)    256         ['conv2d_69[0][0]']
#  ormalization)
#
#  conv2d_70 (Conv2D)             (None, 16, 16, 64)   16384       ['max_pooling2d_7[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 16, 16, 64)   147456      ['max_pooling2d_7[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 16, 16, 64)   147456      ['max_pooling2d_7[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 16, 16, 64)   147456      ['max_pooling2d_7[0][0]']
#
#  activation_68 (Activation)     (None, 1, 1, 64)     0           ['batch_normalization_66[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 16, 16, 64)  256         ['conv2d_70[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 16, 16, 64)  256         ['conv2d_71[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 16, 16, 64)  256         ['conv2d_72[0][0]']
#  ormalization)
#
#  batch_normalization_70 (BatchN  (None, 16, 16, 64)  256         ['conv2d_73[0][0]']
#  ormalization)
#
#  up_sampling2d_17 (UpSampling2D  (None, 16, 16, 64)  0           ['activation_68[0][0]']
#  )
#
#  activation_69 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_67[0][0]']
#
#  activation_70 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_68[0][0]']
#
#  activation_71 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_69[0][0]']
#
#  activation_72 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_70[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 16, 16, 320)  0           ['up_sampling2d_17[0][0]',
#                                                                   'activation_69[0][0]',
#                                                                   'activation_70[0][0]',
#                                                                   'activation_71[0][0]',
#                                                                   'activation_72[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 16, 16, 64)   20480       ['concatenate_17[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 16, 16, 64)  256         ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_71[0][0]']
#
#  up_sampling2d_18 (UpSampling2D  (None, 32, 32, 64)  0           ['activation_73[0][0]']
#  )
#
#  concatenate_18 (Concatenate)   (None, 32, 32, 832)  0           ['up_sampling2d_18[0][0]',
#                                                                   'block4_conv4[0][0]',
#                                                                   'multiply_19[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 32, 32, 256)  1917184     ['concatenate_18[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_75[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_72[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_74[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_73[0][0]']
#
#  global_average_pooling2d_20 (G  (None, 256)         0           ['activation_75[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_20 (Reshape)           (None, 1, 1, 256)    0           ['global_average_pooling2d_20[0][
#                                                                  0]']
#
#  dense_40 (Dense)               (None, 1, 1, 32)     8192        ['reshape_20[0][0]']
#
#  dense_41 (Dense)               (None, 1, 1, 256)    8192        ['dense_40[0][0]']
#
#  multiply_20 (Multiply)         (None, 32, 32, 256)  0           ['activation_75[0][0]',
#                                                                   'dense_41[0][0]']
#
#  up_sampling2d_19 (UpSampling2D  (None, 64, 64, 256)  0          ['multiply_20[0][0]']
#  )
#
#  concatenate_19 (Concatenate)   (None, 64, 64, 640)  0           ['up_sampling2d_19[0][0]',
#                                                                   'block3_conv4[0][0]',
#                                                                   'multiply_18[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 64, 64, 128)  737408      ['concatenate_19[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 64, 64, 128)  512        ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_74[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_76[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 64, 64, 128)  512        ['conv2d_78[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_75[0][0]']
#
#  global_average_pooling2d_21 (G  (None, 128)         0           ['activation_77[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_21 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_21[0][
#                                                                  0]']
#
#  dense_42 (Dense)               (None, 1, 1, 16)     2048        ['reshape_21[0][0]']
#
#  dense_43 (Dense)               (None, 1, 1, 128)    2048        ['dense_42[0][0]']
#
#  multiply_21 (Multiply)         (None, 64, 64, 128)  0           ['activation_77[0][0]',
#                                                                   'dense_43[0][0]']
#
#  up_sampling2d_20 (UpSampling2D  (None, 128, 128, 12  0          ['multiply_21[0][0]']
#  )                              8)
#
#  concatenate_20 (Concatenate)   (None, 128, 128, 32  0           ['up_sampling2d_20[0][0]',
#                                 0)                                'block2_conv2[0][0]',
#                                                                   'multiply_17[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 128, 128, 64  184384      ['concatenate_20[0][0]']
#                                 )
#
#  batch_normalization_76 (BatchN  (None, 128, 128, 64  256        ['conv2d_79[0][0]']
#  ormalization)                  )
#
#  activation_78 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_76[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 128, 128, 64  36928       ['activation_78[0][0]']
#                                 )
#
#  batch_normalization_77 (BatchN  (None, 128, 128, 64  256        ['conv2d_80[0][0]']
#  ormalization)                  )
#
#  activation_79 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_77[0][0]']
#                                 )
#
#  global_average_pooling2d_22 (G  (None, 64)          0           ['activation_79[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_22 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_22[0][
#                                                                  0]']
#
#  dense_44 (Dense)               (None, 1, 1, 8)      512         ['reshape_22[0][0]']
#
#  dense_45 (Dense)               (None, 1, 1, 64)     512         ['dense_44[0][0]']
#
#  multiply_22 (Multiply)         (None, 128, 128, 64  0           ['activation_79[0][0]',
#                                 )                                 'dense_45[0][0]']
#
#  up_sampling2d_21 (UpSampling2D  (None, 256, 256, 64  0          ['multiply_22[0][0]']
#  )                              )
#
#  concatenate_21 (Concatenate)   (None, 256, 256, 16  0           ['up_sampling2d_21[0][0]',
#                                 0)                                'block1_conv2[0][0]',
#                                                                   'multiply_16[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 256, 256, 32  46112       ['concatenate_21[0][0]']
#                                 )
#
#  batch_normalization_78 (BatchN  (None, 256, 256, 32  128        ['conv2d_81[0][0]']
#  ormalization)                  )
#
#  activation_80 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_78[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 256, 256, 32  9248        ['activation_80[0][0]']
#                                 )
#
#  batch_normalization_79 (BatchN  (None, 256, 256, 32  128        ['conv2d_82[0][0]']
#  ormalization)                  )
#
#  activation_81 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_79[0][0]']
#                                 )
#
#  global_average_pooling2d_23 (G  (None, 32)          0           ['activation_81[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_23 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_23[0][
#                                                                  0]']
#
#  dense_46 (Dense)               (None, 1, 1, 4)      128         ['reshape_23[0][0]']
#
#  dense_47 (Dense)               (None, 1, 1, 32)     128         ['dense_46[0][0]']
#
#  multiply_23 (Multiply)         (None, 256, 256, 32  0           ['activation_81[0][0]',
#                                 )                                 'dense_47[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 256, 256, 1)  33          ['multiply_23[0][0]']
#
#  activation_82 (Activation)     (None, 256, 256, 1)  0           ['conv2d_83[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 256, 256, 2)  0           ['activation_59[0][0]',
#                                                                   'activation_82[0][0]']
#
# ==================================================================================================
# Total params: 29,297,570
# Trainable params: 29,290,274
# Non-trainable params: 7,296
# __________________________________________________________________________________________________
